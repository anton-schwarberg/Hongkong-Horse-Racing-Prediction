# %% [markdown]
# # Mapping Notebook

# %% [markdown]
# #### Location Mapping
# > Sha Tin: 1
# > Happy Valley: 0

# %% [markdown]
# #### Going Mapping
# awt_mapping = {
#     'FAST': 0,
#     'GOOD': 1,
#     'WET SLOW': 2,
#     'SLOW': 3,
#     'WET FAST': 4,
#     'SEALED': 5
# }
#
# turf_mapping = {
#     'GOOD TO FIRM': 0,
#     'GOOD': 1,
#     'GOOD TO YIELDING': 2,
#     'YIELDING': 3,
#     'YIELDING TO SOFT': 4,
#     'SOFT': 5,
#     'HEAVY': 6
# }

# %% [markdown]
# #### Info Class mapped

# %% [markdown]
# class_mapping = {
#
#
#     # Gruppe-Rennen (höchste Klasse)
#     'Hong Kong Group One': 1.0,
#     'Group One': 1.0,
#     'Hong Kong Group Two': 2.0,
#     'Group Two': 2.0,
#     'Hong Kong Group Three': 3.0,
#     'Group Three': 3.0,
#
#     # Offene Klassenrennen
#     'Class 1': 4.0,
#     'Class 2': 5.0,
#     'Class 2 (Bonus Prize Money)': 5.1,
#
#     # Alters-/Restriktionsrennen zwischen Class 2 und 3
#     '4 Year Olds': 5.3,
#     'Restricted Race': 5.4,
#     'Griffin Race': 5.5,
#
#     # Class 3 Varianten
#     'Class 3': 6.0,
#     'Class 3 (Bonus Prize Money)': 6.1,
#     'Class 3 (Special Condition)': 6.2,
#     'Class 3 (Restricted)': 6.3,
#
#     # Class 4 Varianten
#     'Class 4': 7.0,
#     'Class 4 (Special Condition)': 7.1,
#     'Class 4 (Bonus Prize Money)': 7.2,
#     'Class 4 (Restricted)': 7.3,
#
#     # Unterste Klasse
#     'Class 5': 8.0,
# }
